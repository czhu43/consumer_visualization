# %%
import pandas as pd
import numpy as np

# %%
file_names = np.array(['data/age.xlsx', 'data/cusize.xlsx', 'data/cucomp.xlsx', 
                       'data/income.xlsx', 'data/race.xlsx', 'data/earners.xlsx'])

# %%
age = pd.read_excel(file_names.item(0))
income = pd.read_excel(file_names.item(3))
race = pd.read_excel(file_names.item(4))
earners = pd.read_excel(file_names.item(5))

# %%
age.transpose().describe()
# Out:
#                                                       0    1    \
# count                                                   1  0.0
# unique                                                  1  0.0
# top     (Aggregates in millions of dollars, unless oth...  NaN
# freq                                                    1  NaN
#
#                         2      3                                       4    \
# count                    10     10                                      10
# unique                   10     10                                      10
# top     75 years\nand older  13199  Percent distribution of consumer units
# freq                      1      1                                       1
#
#         5                                             6    7      8      9    \
# count   0.0                                             1  0.0     10     10
# unique  0.0                                             1  0.0     10     10
# top     NaN  Consumer unit characteristics (mean values):  NaN  69062  75609
# freq    NaN                                             1  NaN      1      1
#
#                               ...                           179  180   181  \
# count                         ...                          10.0  0.0  10.0
# unique                        ...                          10.0  0.0  10.0
# top                           ...                          15.7  NaN  15.7
# freq                          ...                           1.0  NaN   1.0
#
#         182                               183  \
# count   0.0                                 1
# unique  0.0                                 1
# top     NaN  a Value is too small to display.
# freq    NaN                                 1
#
#                                                      184  185  186  187  \
# count                                                  1  0.0  0.0  0.0
# unique                                                 1  0.0  0.0  0.0
# top     b Data are likely to have large sampling errors.  NaN  NaN  NaN
# freq                                                   1  NaN  NaN  NaN
#
#                                                       188
# count                                                   1
# unique                                                  1
# top     Source: Consumer Expenditure Survey, U.S. Bure...
# freq                                                    1
#
# [4 rows x 189 columns]
